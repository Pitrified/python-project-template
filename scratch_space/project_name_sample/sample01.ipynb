# %% [markdown]
# # Sample of the `project_name` config

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from rich import print as rprint

# %%
from project_name.config.project_name_config import get_project_name_config

# %%
c = get_project_name_config()
rprint(c)
# Out:
# 2025-02-18 22:34:06.155 | INFO     | project_name.config.project_name_config:__init__:14 - Loading ProjectName config
# ProjectNameConfig:
# ProjectNamePaths:
#    src_fol: /home/pmn/repos/python_project_template/src/project_name
#   root_fol: /home/pmn/repos/python_project_template
#  cache_fol: /home/pmn/repos/python_project_template/cache
#   data_fol: /home/pmn/repos/python_project_template/data
# static_fol: /home/pmn/repos/python_project_template/static
